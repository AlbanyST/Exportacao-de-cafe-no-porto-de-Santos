# %%
import sys
sys.path.append("..")
from src.preprocessing import (
    carregar_dados,
    filtrar_santos,
    filtrar_cafe,
    converter_sacas
)
import pandas as pd

# %%
df = carregar_dados("../data/raw/")
df.head()
# Out:
#    CO_ANO  CO_MES   CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 0    2016      11  9011110       21       87        ES       1  817800
# 1    2016      11  9011110       21      386        SP       1  817800
# 2    2016       7  9011110       21       23        MG       1  817800
# 3    2016      11  9011110       21      427        MG       1  817800
# 4    2016      11  9011110       21      246        SP       1  817800
#
#    QT_ESTAT  KG_LIQUIDO    VL_FOB          Sacas
# 0       215      214985    624472    3583.083333
# 1      1359     1359862   4239322   22664.366667
# 2     14608    14610260  37494338  243504.333333
# 3        20       20040     54586     334.000000
# 4       122      122400    298824    2040.000000

# %%
df["Data"] = pd.to_datetime(
    df["CO_ANO"].astype(str) + "-" + df["CO_MES"].astype(str)
)

# %%
df.to_csv("../data/processed/cafe_limpo.csv", index=False)
